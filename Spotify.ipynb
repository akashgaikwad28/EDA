# %% [markdown]
# <a href="https://colab.research.google.com/github/akashgaikwad28/EDA/blob/main/Spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Spotify

# %% [markdown]
#  **Description of the Dataset:**
#
#  The dataset titled "Spotify Data: Popular Hip-hop Artists and Tracks" provides a curated collection of
# approximately 500 entries showcasing the vibrant realm of hip-hop music. These entries meticulously compile
# the most celebrated hip-hop tracks and artists, reflecting their significant influence on the genre's landscape.
# Each entry not only highlights the popularity and musical composition of the tracks but also underscores the
# creative prowess of the artists and their profound impact on global listeners.
#
# **Application in Data Science:**
#
#  This dataset serves as a valuable resource for various data science explorations. Analysts can delve into trend
# analysis to discern the popularity dynamics of hit hip-hop tracks over recent years. Additionally, the dataset
# enables network analysis to uncover collaborative patterns among top artists, shedding light on the genre's
# evolving collaborative landscape. Furthermore, it facilitates the development of predictive models aimed at
# forecasting track popularity based on diverse features, offering insights for artists, producers, and marketers
#
# **Column Descriptors:**
#
#  Artist: The name of the artist, providing direct attribution to the creative mind behind the track.
#  Track Name: The title of the track, encapsulating its identity and essence.
#  Popularity: A numeric score reflecting the track's reception and appeal among Spotify listeners.
#  Duration (ms): The track's length in milliseconds, detailing the temporal extent of the musical experience.
#  Track ID: A unique identifier within Spotify's ecosystem, enabling direct access to the track for further
# exploration.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/spotify.csv')

# %%
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %% [markdown]
# Read the dataframe, check null value if present then do the needful, check duplicate row , if present then do
# the needful

# %%
df.shape
# Out:
# (440, 5)

# %%
df.isnull().sum()
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %%
cols  = df.columns

# %%
cols
# Out:
# Index(['Artist', 'Track Name', 'Popularity', 'Duration (ms)', 'Track ID'], dtype='object')

# %%
for col in cols:
  print(col)
  print(df[col].unique())
# Out:
# ['Drake' 'Travis Scott' 'Post Malone' 'Noah Kahan' 'Nicki Minaj'
#  'Justin Bieber' 'Jessie J' 'KAROL G' '21 Savage' 'Metro Boomin' 'SZA'
#  'Jack Harlow' 'Jung Kook' 'Lil Nas X' 'Lyrical Lemonade' 'Future'
#  'Don Toliver' 'Lil Wayne' 'Yeat' 'Eminem' 'Kendrick Lamar' 'Baby Keem'
#  'The Weeknd' 'JAY-Z' 'Cardi B' 'Bruno Mars' 'Ed Sheeran' 'GloRilla'
#  'Gunna' 'Lil Baby' 'Internet Money' 'Sarz' 'J. Cole' 'Lil Durk' 'cassö'
#  'D-Block Europe' 'Clavish' 'Latto' 'Young Nudy' 'Megan Thee Stallion'
#  'NEIKED' 'Snoop Dogg' 'Dr. Dre' 'benny blanco' 'Young Thug' 'Chris Brown'
#  'Dave' 'Central Cee' 'The Kid LAROI' 'Quevedo' 'Bizarrap' 'Anuel AA'
#  'SAIKO' 'David Guetta' 'Coi Leray' 'Pressa' 'Fivio Foreign' 'RAYE'
#  'French Montana' 'Arizona Zervas' 'Pharrell Williams' 'XXXTENTACION'
#  'Kane Brown' 'Ellie Goulding' 'Reneé Rapp' 'Maroon 5' 'DJ Snake' 'Quavo'
#  'DJ Khaled' 'ATL Jacob' 'Jason Derulo' 'Kanye West' 'Trueno'
# ...

# %%
print("Checking for duplicate rows:")
duplicates = df.duplicated().sum()
print(f"Total number of duplicate rows: {duplicates}")
# Out:
# Checking for duplicate rows:
# Total number of duplicate rows: 27

# %%
# Remove duplicates if present
if duplicates > 0:
    df = df.drop_duplicates()
    print("Duplicate rows removed.")
else:
    print("No duplicate rows found.")
# Out:
# Duplicate rows removed.

# %%
df.shape
# Out:
# (413, 5)

# %%
print("Cleaned dataset:")
df.head()
# Out:
# Cleaned dataset:
#   Artist                               Track Name  Popularity  Duration (ms)  \
# 0  Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92         319191
# 1  Drake                                One Dance          91         173986
# 2  Drake                       IDGAF (feat. Yeat)          90         260111
# 3  Drake     First Person Shooter (feat. J. Cole)          88         247444
# 4  Drake            Jimmy Cooks (feat. 21 Savage)          88         218364
#
#                  Track ID
# 0  1yeB8MUNeLo9Ek1UEpsyz6
# 1  1zi7xx7UVEFkmKfv06H8x0
# 2  2YSzYUF3jWqb9YP9VXmpjE
# 3  7aqfrAY2p9BUSiupwk3svU
# 4  3F5CgOj3wFlRv51JsHbxhe

# %% [markdown]
# What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram

# %%
#  Check the distribution of the 'Popularity' column using a histogram
plt.figure(figsize=(10, 6))
plt.hist(df['Popularity'], bins=20, color='skyblue', edgecolor='black')

# Step 3: Add labels and title for clarity
plt.title('Distribution of Popularity Among Tracks')
plt.xlabel('Popularity Score')
plt.ylabel('Frequency')

# Step 4: Display the histogram
plt.show()

# %% [markdown]
# Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot

# %%
#  Create a scatter plot to visualize the relationship between 'Popularity' and 'Duration (ms)'
plt.figure(figsize=(10, 6))
plt.scatter(df['Duration (ms)'], df['Popularity'], color='skyblue', edgecolor='black', alpha=0.6)

# Step 3: Add labels and title for clarity
plt.title('Relationship Between Popularity and Duration of Tracks')
plt.xlabel('Duration (ms)')
plt.ylabel('Popularity')

# Step 4: Display the scatter plot
plt.show()

# %%
## randomness  no such relation

# %% [markdown]
# Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using
# a countplot

# %%
# Step 2: Count the number of tracks per artist
artist_track_counts = df['Artist'].value_counts()

# Step 3: Create a countplot to visualize the count of tracks for each artist
plt.figure(figsize=(12, 8))
sns.countplot(data=df, x='Artist', order=artist_track_counts.index, palette='Set2')

# Step 4: Rotate x-axis labels for better readability (if there are many artists)
plt.xticks(rotation=90)

# Step 5: Add title and labels for clarity
plt.title('Count of Tracks for Each Artist')
plt.xlabel('Artist')
plt.ylabel('Number of Tracks')

# Step 6: Display the plot
plt.show()

# Step 7: Display the artist with the highest number of tracks
most_tracks_artist = artist_track_counts.idxmax()
most_tracks_count = artist_track_counts.max()

print(f'The artist with the highest number of tracks is "{most_tracks_artist}" with {most_tracks_count} tracks.')
# Out:
# The artist with the highest number of tracks is "Drake" with 17 tracks.

# %% [markdown]
# What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each

# %%
# Sort the dataset by 'Popularity' in ascending order to get least popular tracks
least_popular_tracks = df.sort_values(by='Popularity', ascending=True).head(5)

# Step 3: Display the artist and track name for the least popular tracks
least_popular_tracks_info = least_popular_tracks[['Artist', 'Track Name', 'Popularity']]

# Step 4: Print the result
print("Top 5 Least Popular Tracks:")
print(least_popular_tracks_info)
# Out:
# Top 5 Least Popular Tracks:
#              Artist                     Track Name  Popularity
# 207          Pressa  Attachments (feat. Coi Leray)          29
# 231   Justin Bieber                     Intentions          35
# 413  French Montana                Splash Brothers          44
# 225        Lil Baby                  On Me - Remix          47
# 407     Wyclef Jean      911 (feat. Mary J. Blige)          48

# %% [markdown]
# Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and
# display the average popularity for each artist

# %%
# Step 2: Group by artist and calculate average popularity
artist_avg_popularity = df.groupby('Artist')['Popularity'].mean().sort_values(ascending=False)

# Step 3: Get the top 5 most popular artists
top_5_artists = artist_avg_popularity.head(5)

# Step 4: Display the average popularity for each of the top 5 most popular artists
print("Top 5 Artists with Highest Average Popularity:")
print(top_5_artists)

# Step 5: Find the artist with the highest average popularity among the top 5
highest_avg_popularity_artist = top_5_artists.idxmax()
highest_avg_popularity_value = top_5_artists.max()

print(f"\nThe artist with the highest average popularity among the top 5 is '{highest_avg_popularity_artist}' with an average popularity of {highest_avg_popularity_value:.2f}.")
# Out:
# Top 5 Artists with Highest Average Popularity:
# Artist
# cassö           92.000000
# Trueno          89.000000
# David Guetta    87.000000
# Travis Scott    86.555556
# ¥$              85.100000
# Name: Popularity, dtype: float64
#
# The artist with the highest average popularity among the top 5 is 'cassö' with an average popularity of 92.00.

# %% [markdown]
#  For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist

# %%
# Step 2: Group by artist and calculate average popularity
artist_avg_popularity = df.groupby('Artist')['Popularity'].mean().sort_values(ascending=False)

# Step 3: Get the top 5 most popular artists
top_5_artists = artist_avg_popularity.head(5)

# Step 4: Initialize a dictionary to store the most popular track for each artist
most_popular_tracks = {}

# Step 5: For each artist in the top 5, find their most popular track
for artist in top_5_artists.index:
    # Filter the dataset for the current artist
    artist_tracks = df[df['Artist'] == artist]

    # Find the track with the highest popularity for this artist
    most_popular_track = artist_tracks.loc[artist_tracks['Popularity'].idxmax()]

    # Store the track name in the dictionary
    most_popular_tracks[artist] = most_popular_track['Track Name']

# Step 6: Display the most popular track for each artist
print("Most Popular Tracks for the Top 5 Artists:")
for artist, track in most_popular_tracks.items():
    print(f"{artist}: {track}")
# Out:
# Most Popular Tracks for the Top 5 Artists:
# cassö: Prada
# Trueno: Mamichula - con Nicki Nicole
# David Guetta: Baby Don't Hurt Me
# Travis Scott: FE!N (feat. Playboi Carti)
# ¥$: CARNIVAL

# %% [markdown]
# Visualize relationships between multiple numerical variables simultaneously using a pair plot

# %%
# Select numerical columns for the pair plot
numerical_columns = ['Popularity', 'Duration (ms)', 'Track ID']

# Step 3: Create the pair plot
sns.pairplot(df[numerical_columns])

# Step 4: Display the plot
plt.show()

# %% [markdown]
# Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or
# violin plot

# %%
# Step 2: Create a box plot or violin plot to explore the distribution of track durations across artists
plt.figure(figsize=(12, 6))  # Adjust the figure size for better readability

# Option 1: Box plot
sns.boxplot(x='Artist', y='Duration (ms)', data=df)

# Option 2: Violin plot (Uncomment if you want to use a violin plot instead)
# sns.violinplot(x='Artist', y='Duration (ms)', data=df)

# Step 3: Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Step 4: Display the plot
plt.title('Track Duration Distribution Across Different Artists')
plt.show()

# %% [markdown]
# How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a
# violin plot

# %%
# Create a swarm plot or violin plot to explore the distribution of track popularity across artists
plt.figure(figsize=(12, 6))  # Adjust the figure size for better readability

# Option 1: Swarm plot
sns.swarmplot(x='Artist', y='Popularity', data=df)

# Option 2: Violin plot (Uncomment if you want to use a violin plot instead)
# sns.violinplot(x='Artist', y='Popularity', data=df)

# Step 3: Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Step 4: Display the plot
plt.title('Track Popularity Distribution Across Different Artists')
plt.show()
